# %%
import pandas as pd
import matplotlib.pyplot as plt

turn_data = [24,22,20,14]

turn = pd.Series(turn_data)
turn.index = ['Novak Djovokic','Rafael Nadal','Roger Federer','Pete Sampras']

turn.plot(kind='bar', title='Won turnaments by player', xlabel='Tennis player', ylabel='Amount of won turnaments')
# Out:
# <Axes: title={'center': 'Won turnaments by player'}, xlabel='Tennis player', ylabel='Amount of won turnaments'>
